# %% [markdown]
# # Explore Generated KODC Outputs
#
# Run `pixi run analyze` first. This notebook intentionally reads generated tables only; the reproducible pipeline lives in `src/kodc/`.

# %%
from pathlib import Path

import pandas as pd

output_dir = Path("../outputs/tables")
line_anomalies = pd.read_csv(output_dir / "line208_anomalies.csv", parse_dates=["obs_dtm"])
variance = pd.read_csv(output_dir / "line208_variance.csv")

display(line_anomalies.head())
display(variance)
